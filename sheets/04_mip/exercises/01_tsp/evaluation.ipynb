# %% [markdown]
# # Analyzing the Linear Relaxation

# %%
from _evaluation import (  # the code has been moved to a separate file
    get_sample,
    n,
    samples,
)

# %% [markdown]
# ## Getting a sample solution
#
# The following code will create a random instance and solve
#
# 1. The linear relaxation with `>=2` subtour elimination constraints
# 2. The linear relaxation with `>=1` subtour elimination constraints
# 3. The integer programming problem to get an optimal solution
#
# It will plot the solutions for you to compare and save the results in the `samples` list.
#
# In the plots, the red lines represent fractional edges, i.e., edges with a value between 0 and 1.
# The green lines represent edges where the linear relaxation and the optimal solution agree.
# The title will show the objective value of the solution or the overlap between the linear relaxation and the optimal solution.

# %%
# Run me to get a sample on linear relaxation and integral solution
get_sample()
print(f"There are now {len(samples)} samples")
# Out:
# Solving the linear relaxation with k=2
# Set parameter Username
# Set parameter LicenseID to value 2734354
# Academic license - for non-commercial use only - expires 2026-11-07
# Set parameter LogToConsole to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.3.0 22D68)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 201 rows, 19900 columns and 59700 nonzeros
# Model fingerprint: 0x289ab52b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 200 rows, 19900 columns, 39800 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.990e+04
#  Factor NZ  : 2.010e+04 (roughly 8 MB of memory)
#  Factor Ops : 2.687e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.03 seconds (0.03 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      291    1.0219000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 291 iterations and 0.03 seconds (0.04 work units)
# Optimal objective  1.021900000e+04
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.3.0 22D68)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 220 rows, 19900 columns and 93776 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0219000e+04   3.800000e+01   0.000000e+00      0s
#       54    1.0635000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 54 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.063500000e+04
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.3.0 22D68)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 224 rows, 19900 columns and 109106 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0635000e+04   8.000000e+00   0.000000e+00      0s
#        9    1.0671500e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.067150000e+04
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.3.0 22D68)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 227 rows, 19900 columns and 120032 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0671500e+04   6.000000e+00   0.000000e+00      0s
#       12    1.0692000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 12 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.069200000e+04
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.3.0 22D68)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 230 rows, 19900 columns and 123506 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0692000e+04   6.000000e+00   0.000000e+00      0s
#       15    1.0721500e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 15 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.072150000e+04
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.3.0 22D68)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 233 rows, 19900 columns and 126232 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0721500e+04   6.000000e+00   0.000000e+00      0s
#        5    1.0730000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.073000000e+04
# Solving the integral problem
# Set parameter LogToConsole to value 1
# Set parameter TimeLimit to value 30
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0.001
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.3.0 22D68)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Non-default parameters:
# TimeLimit  30
# MIPGap  0.001
# LazyConstraints  1
#
# Optimize a model with 201 rows, 19900 columns and 59700 nonzeros
# Model fingerprint: 0xc265f80e
# Variable types: 0 continuous, 19900 integer (19900 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Presolve time: 0.04s
# Presolved: 201 rows, 19900 columns, 59304 nonzeros
# Variable types: 0 continuous, 19900 integer (19900 binary)
#
# Root relaxation: objective 1.021900e+04, 199 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 10219.0000    0   24          - 10219.0000      -     -    0s
#      0     0 10635.0000    0   28          - 10635.0000      -     -    0s
#      0     0 10646.5000    0   40          - 10646.5000      -     -    0s
#      0     0 10652.7500    0   46          - 10652.7500      -     -    0s
#      0     0 10654.6667    0   55          - 10654.6667      -     -    0s
#      0     0 10656.5000    0   55          - 10656.5000      -     -    0s
#      0     2 10656.5000    0   55          - 10656.5000      -     -    0s
# * 1598  1405             113    11243.000000 10666.2500  5.13%   8.5    1s
# * 1640   992              35    11079.000000 10666.2500  3.73%   8.5    1s
# H 1836   993                    10978.000000 10732.0000  2.24%   8.5    2s
# H 1836   944                    10972.000000 10732.0000  2.19%   8.5    2s
# H 1836   896                    10840.000000 10732.0000  1.00%   8.5    2s
# H 1841   855                    10827.000000 10770.7000  0.52%   8.6    2s
# H 1842   813                    10821.000000 10777.6667  0.40%   8.6    2s
# H 1866   789                    10813.000000 10805.5694  0.07%   9.1    3s
#
# Cutting planes:
#   Gomory: 20
#   Cover: 2
#   Flow cover: 4
#   Zero half: 10
#   Lazy constraints: 1
#
# Explored 1866 nodes (17783 simplex iterations) in 3.38 seconds (3.73 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 8: 10813 10821 10827 ... 11243
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 1.081300000000e+04, best bound 1.080600000000e+04, gap 0.0647%
#
# User-callback calls 4898, time in user-callback 0.80 sec
# Solving the linear relaxation with k=1
# Set parameter LogToConsole to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.3.0 22D68)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 201 rows, 19900 columns and 59700 nonzeros
# Model fingerprint: 0x289ab52b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 200 rows, 19900 columns, 39800 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.990e+04
#  Factor NZ  : 2.010e+04 (roughly 8 MB of memory)
#  Factor Ops : 2.687e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.03 seconds (0.03 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      291    1.0219000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 291 iterations and 0.03 seconds (0.04 work units)
# Optimal objective  1.021900000e+04
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.3.0 22D68)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 220 rows, 19900 columns and 93776 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0219000e+04   1.900000e+01   0.000000e+00      0s
#       53    1.0419750e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 53 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.041975000e+04
# Objective value: 10813.0, Linear relaxation k=2 value: 10730.0, Overlap: 184/200
# Objective value: 10813.0, Linear relaxation k=1 value: 10419.75, Overlap: 174/200
# There are now 1 samples

# %%
for i, (objective_value, linear_relaxation_value, overlap) in enumerate(samples):
    print(
        f"Sample {i}: Objective value: {objective_value}, Linear relaxation value (>=2): {linear_relaxation_value}, Overlap: {overlap}/{n}"
    )
# Out:
# Sample 0: Objective value: 10813.0, Linear relaxation value (>=2): 10730.0, Overlap: 184/200
